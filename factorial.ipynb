# %%
num=int(input("enter non negative number to get factorial"))
fact=1
for i in range(num):
 fact=fact*(i+1);

print('factorial of',num,'=',fact)
# Out:
# enter non negative number to get factorial7
# factorial of 7 = 5040
