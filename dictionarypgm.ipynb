# %%
y = {'John':40,'Alex':2,'Benny':32,'Denny':3}
l=list(y.items())
l.sort()
print('Ascending order is',l)
l=list(y.items())
l.sort(reverse=True)
print('Descending Order is',l)
# Out:
# Ascending order is [('Alex', 2), ('Benny', 32), ('Denny', 3), ('John', 40)]
# Descending Order is [('John', 40), ('Denny', 3), ('Benny', 32), ('Alex', 2)]
