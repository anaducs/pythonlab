# %%
from math import pi
r = (float(input("Input the radius of circle:")))
print("The area of circle with radius"+str(r)+"is:" +str(pi*r**2))
# Out:
# Input the radius of circle:4
# The area of circle with radius4.0is:50.26548245743669
