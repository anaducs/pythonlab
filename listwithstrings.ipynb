# %%
lst2=['red','blue','green','yellow','black']
lst2.sort()
print('Sorted strings in ascending order',lst2)
lst2.sort(reverse=True)
print('Sorted strings in descending order',lst2)
lst3=['red','blue','green','yellow','black']
lst3.sort()
print('Sorted strings in ascending order',lst3)
lst3.sort(reverse=True)
print('Sorted strings in descending order',lst3)
# Out:
# Sorted strings in ascending order ['black', 'blue', 'green', 'red', 'yellow']
# Sorted strings in descending order ['yellow', 'red', 'green', 'blue', 'black']
# Sorted strings in ascending order ['black', 'blue', 'green', 'red', 'yellow']
# Sorted strings in descending order ['yellow', 'red', 'green', 'blue', 'black']
