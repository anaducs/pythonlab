# %%
lst1=eval(input("Enter first list"))
lst2=eval(input("Enter second list"))
l=len(lst1)
lst3=[]
for a in range(0,l):
   s=lst1[a]+lst2[a]
   lst3.append(s)
print("List 1",lst1)
print("List 2",lst2)
print("New list is",lst3)
# Out:
# Enter first list4,5,6
# Enter second list7,8,9
# List 1 (4, 5, 6)
# List 2 (7, 8, 9)
# New list is [11, 13, 15]
