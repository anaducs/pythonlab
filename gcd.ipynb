# %%
n1=int(input("enter 1st number:"))
n2=int(input("enter 2nd number:"))
if n1>n2:
  min=n2
else:
  min=n1
for i in range(1,min+1):
  if n1%i==0 and n2%i==0:
     gcd=i
print("gcd of 2 number is",gcd)
# Out:
# enter 1st number:12
# enter 2nd number:78
# gcd of 2 number is 6
