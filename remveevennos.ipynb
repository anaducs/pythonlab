# %%
list=[11,22,33,44,55]
print("Original list")
   print(list)
 for i in list:
     list.remove(1)
print("list after removing even numbers:")
print(list)
# Out:
#   File "<ipython-input-4-b20cecac3837>", line 3
#     print(list)
#     ^
# IndentationError: unexpected indent

# %%
lisinput
