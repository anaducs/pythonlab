# %%
import csv
with open('Harigovind.csv',newline='') as csvfile:
    data=csv.DictReader(csvfile)
    print("ID Employee Name")
    print("-------------------")
    for row in data:
        print(row['Empid'],row['Name'])
