# %%
mklst=[]
total=0
n=int(input('Enter the no of students'))
for a in range(n):
   print('Student',a+1)
   mk=float(input('Enter marks of students'))
   mklst.append(mk)
avg=total/n
print('Marks of',n,'students')
print(mklst)
print('Average marks of',n,'student is',avg)
# Out:
# Enter the no of students3
# Student 1
# Enter marks of students45
# Student 2
# Enter marks of students55
# Student 3
# Enter marks of students65
# Marks of 3 students
# [45.0, 55.0, 65.0]
# Average marks of 3 student is 0.0
