# %%
def char_frequency(str1):
  dict={}
  for n in str1:
    keys=dict.keys()
    if n in keys:
      dict[n]+=1
    else:
      dict[n]=1
    return dict
string_value=input("Enter a string: ")
print(char_frequency(string_value))
# Out:
# Enter a string: lachu
# {'l': 1}
