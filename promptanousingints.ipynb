# %%
list1 = []
n=int(input("Enter a Limit"))
i=0
while i<n:
     i=i+1
     inp = int(input("Enter an integer : "))
     if(inp < 100):
         list1.append(inp)
     else:
         list1.append("Over")

print("List is:",list1)
# Out:
# Enter a Limit4
# Enter an integer : 5
# Enter an integer : 6
# Enter an integer : 7
# Enter an integer : 8
# List is: [5, 6, 7, 8]
